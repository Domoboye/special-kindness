# %%
import pandas as pd
data_frame = pd.read_csv('fuel_ferc1.csv')
data_frame.shape
# Out:
# (29523, 11)

# %%
data_frame.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
data_frame.values
# Out:
# array([['f1_fuel_1994_12_1_0_7', 1, 1994, ..., 18.59, 18.53, 1.121],
#        ['f1_fuel_1994_12_1_0_10', 1, 1994, ..., 18.58, 18.53, 1.12],
#        ['f1_fuel_1994_12_2_0_1', 2, 1994, ..., 39.72, 38.12, 1.65],
#        ...,
#        ['f1_fuel_2018_12_12_1_10', 12, 2018, ..., 4.77, 4.77, 8.99],
#        ['f1_fuel_2018_12_12_1_13', 12, 2018, ..., 3.06, 14.76, 1.11],
#        ['f1_fuel_2018_12_12_1_14', 12, 2018, ..., 0.0, 0.0, 11.68]],
#       dtype=object)

# %%
data_frame[data_frame['fuel_cost_per_unit_burned']> 26.000000]
# Out:
#        index                 record_id  utility_id_ferc1  report_year  \
# 2          2     f1_fuel_1994_12_2_0_1                 2         1994
# 3          3     f1_fuel_1994_12_2_0_7                 2         1994
# 5          5    f1_fuel_1994_12_2_0_13                 2         1994
# 6          6     f1_fuel_1994_12_2_1_1                 2         1994
# 7          7    f1_fuel_1994_12_2_1_10                 2         1994
# ...      ...                       ...               ...          ...
# 29323  29503  f1_fuel_2018_12_191_1_14               191         2018
# 29325  29505   f1_fuel_2018_12_432_0_2               432         2018
# 29326  29506   f1_fuel_2018_12_432_0_5               432         2018
# 29327  29507   f1_fuel_2018_12_432_0_8               432         2018
# 29328  29508  f1_fuel_2018_12_432_0_11               432         2018
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# ...

# %%
data_frame.sort_values('fuel_cost_per_unit_burned', ascending=False).head()
# Out:
#        index                record_id  utility_id_ferc1  report_year  \
# 24971  25127  f1_fuel_2014_12_147_0_2               147         2014
# 20581  20719  f1_fuel_2011_12_132_1_2               132         2011
# 24426  24577  f1_fuel_2014_12_177_2_7               177         2014
# 21343  21483   f1_fuel_2011_12_7_7_13                 7         2011
# 22843  22991   f1_fuel_2012_12_7_7_13                 7         2012
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 24971          san juan                 oil       bbl          49418.0
# 20581            solway                 oil       bbl            150.0
# 24426  howard bend c.t.                 oil       bbl             76.0
# 21343      palo verde 2             nuclear       kgU            467.0
# 22843      palo verde 2             nuclear       kgU            465.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 24971             6.172572                 139358.000
# ...

# %%
data_frame.isnull()
# Out:
#        record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# 0          False             False        False             False
# 1          False             False        False             False
# 2          False             False        False             False
# 3          False             False        False             False
# 4          False             False        False             False
# ...          ...               ...          ...               ...
# 29518      False             False        False             False
# 29519      False             False        False             False
# 29520      False             False        False             False
# 29521      False             False        False             False
# 29522      False             False        False             False
#
#        fuel_type_code_pudl  fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                    False      False            False                False
# ...

# %%
data_frame[pd.isnull(data_frame).any(axis=1)]
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 66       f1_fuel_1994_12_9_3_13                 9         1994
# 152      f1_fuel_1994_12_8_1_14                 8         1994
# 277      f1_fuel_1994_12_74_0_3                74         1994
# 626     f1_fuel_1994_12_117_0_1               117         1994
# 627     f1_fuel_1994_12_117_0_4               117         1994
# ...                         ...               ...          ...
# 28413  f1_fuel_2017_12_227_0_13               227         2017
# 28828  f1_fuel_2018_12_148_0_12               148         2018
# 28830  f1_fuel_2018_12_148_0_14               148         2018
# 29052   f1_fuel_2018_12_162_0_1               162         2018
# 29053   f1_fuel_2018_12_162_0_4               162         2018
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 66            mickleton                 oil       NaN           3547.0
# ...

# %%
data_frame= data_frame.dropna()
data_frame= data_frame.reset_index()
data_frame
# Out:
#        index                record_id  utility_id_ferc1  report_year  \
# 0          0    f1_fuel_1994_12_1_0_7                 1         1994
# 1          1   f1_fuel_1994_12_1_0_10                 1         1994
# 2          2    f1_fuel_1994_12_2_0_1                 2         1994
# 3          3    f1_fuel_1994_12_2_0_7                 2         1994
# 4          4   f1_fuel_1994_12_2_0_10                 2         1994
# ...      ...                      ...               ...          ...
# 29338  29518  f1_fuel_2018_12_12_0_13                12         2018
# 29339  29519   f1_fuel_2018_12_12_1_1                12         2018
# 29340  29520  f1_fuel_2018_12_12_1_10                12         2018
# 29341  29521  f1_fuel_2018_12_12_1_13                12         2018
# 29342  29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# ...

# %%
data_frame.duplicated().any()
# Out:
# False

# %%
data_frame.isnull().sum()
# Out:
#   File "<ipython-input-35-db1b15aa0a0c>", line 1
#     data_frame.isnull()=True
#                             ^
# SyntaxError: can't assign to function call

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit=pd.DataFrame({'unit':['BBL','GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'], 'count':[7998,84,464,110,11354,180,95,100,8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
g=sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale('log')
g.set_ylim(1,12000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
sns.boxplot(x='fuel_type_code_pudl', y='utility_id_ferc1', palette= ['m', 'g'], data= data_frame)

# %%
sample_df= data_frame.sample(n=50, random_state=4)
sns.regplot(x=sample_df['utility_id_ferc1'], y=sample_df["fuel_cost_per_mmbtu"], fit_reg=False)

# %%
data_frame.to_csv('fuel.csv', index=False)

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29343 entries, 0 to 29342
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         29343 non-null  int64
#  1   record_id                     29343 non-null  object
#  2   utility_id_ferc1              29343 non-null  int64
#  3   report_year                   29343 non-null  int64
#  4   plant_name_ferc1              29343 non-null  object
#  5   fuel_type_code_pudl           29343 non-null  object
#  6   fuel_unit                     29343 non-null  object
#  7   fuel_qty_burned               29343 non-null  float64
#  8   fuel_mmbtu_per_unit           29343 non-null  float64
#  9   fuel_cost_per_unit_burned     29343 non-null  float64
#  10  fuel_cost_per_unit_delivered  29343 non-null  float64
#  11  fuel_cost_per_mmbtu           29343 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# ...
